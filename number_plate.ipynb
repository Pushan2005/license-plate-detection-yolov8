# %% [markdown]
# # Running Step 1:

# %%
# !git clone https://github.com/Pushan2005/license-plate-detection-yolov8.git
# Out:
# Cloning into 'license-plate-detection-yolov8'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 116 (delta 19), reused 116 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (116/116), 5.59 MiB | 7.97 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %% [markdown]
# # Running Step 2:

# %%
cd /content/license-plate-detection-yolov8
# Out:
# /content/license-plate-detection-yolov8

# %%
# !pip install roboflow -q

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("mochoye").project("license-plate-detector-ogxxg")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 94.8 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plate-Detector-2 in yolov8:: 100%|██████████| 802/802 [00:00<00:00, 5337.06it/s]

# %% [markdown]
# # Running Step 3:

# %%
# !pip install -r requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Running Step 4:

# %%
# prompt: uninstall torch audio
# specifying for transparency: this cell was written using AI

# !pip uninstall torchaudio -y
# Out:
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
# Out:
# CUDA Available: False

# %%
#!pip install torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124

# %%
# !pip install torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cpu -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.9 MB/s eta 0:00:00

# %% [markdown]
# training command:

# %%
# !python /content/license-plate-detection-yolov8/ultralytics/yolo/v8/detect/train.py model=yolov8n.pt data=/content/license-plate-detection-yolov8/License-Plate-Detector-2/data.yaml epochs=100
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 103MB/s]
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py:341: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# %ls
# Out:
# best.pt  dataset.txt  requirements.txt  ultralytics/

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/results.png (deflated 13%)
#   adding: runs/detect/train/predictions.json (deflated 82%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/weights/best.pt (deflated 10%)
#   adding: runs/detect/train/weights/last.pt (deflated 10%)
#   adding: runs/detect/train/results.csv (deflated 89%)
#   adding: runs/detect/train/events.out.tfevents.1743439846.38cf2702d362.2950.0 (deflated 71%)
#   adding: runs/detect/train/F1_curve.png (deflated 15%)
#   adding: runs/detect/train/R_curve.png (deflated 16%)
#   adding: runs/detect/train/PR_curve.png (deflated 23%)
#   adding: runs/detect/train/confusion_matrix.png (deflated 38%)
#   adding: runs/detect/train/args.yaml (deflated 50%)
#   adding: runs/detect/train/P_curve.png (deflated 20%)

# %%
from google.colab import files
files.download('runs.zip')

# %% [markdown]
# unzip runs file after uploading

# %%
# !unzip runs.zip
# Out:
# Archive:  runs.zip
#    creating: runs/
#    creating: runs/detect/
#    creating: runs/detect/train/
#   inflating: runs/detect/train/results.png
#   inflating: runs/detect/train/predictions.json
#    creating: runs/detect/train/weights/
#   inflating: runs/detect/train/weights/best.pt
#   inflating: runs/detect/train/weights/last.pt
#   inflating: runs/detect/train/results.csv
#   inflating: runs/detect/train/events.out.tfevents.1743439846.38cf2702d362.2950.0
#   inflating: runs/detect/train/F1_curve.png
#   inflating: runs/detect/train/R_curve.png
#   inflating: runs/detect/train/PR_curve.png
#   inflating: runs/detect/train/confusion_matrix.png
#   inflating: runs/detect/train/args.yaml
#   inflating: runs/detect/train/P_curve.png

# %% [markdown]
# # Running Step 5:
# upload the image/video and specify the location in the source='' section of the following cell before running

# %%
# !python /content/license-plate-detection-yolov8/ultralytics/yolo/v8/detect/predict.py model='/content/license-plate-detection-yolov8/runs/detect/train/weights/best.pt' source='/content/license-plate-detection-yolov8/plate.jpg'
# Out:
# 2025-04-03 05:24:17.013116: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743657857.376077    3135 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743657857.484512    3135 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-03 05:24:18.250086: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
